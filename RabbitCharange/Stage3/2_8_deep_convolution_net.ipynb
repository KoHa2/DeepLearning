# %% [markdown]
# <a href="https://colab.research.google.com/github/KoHa2/DeepLearning/blob/main/RabbitCharange/Stage3/2_8_deep_convolution_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/E/03.stage3/DNN_code_colab_lesson_1_2')

# %% [markdown]
# # deep convolution network

# %%
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from common import optimizer

class DeepConvNet:
    '''
    認識率99%以上の高精度なConvNet

    conv - relu - conv- relu - pool -
    conv - relu - conv- relu - pool -
    conv - relu - conv- relu - pool -
    affine - relu - dropout - affine - dropout - softmax
    '''
    def __init__(self, input_dim=(1, 28, 28),
                 conv_param_1 = {'filter_num':16, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_2 = {'filter_num':16, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_3 = {'filter_num':32, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_4 = {'filter_num':32, 'filter_size':3, 'pad':2, 'stride':1},
                 conv_param_5 = {'filter_num':64, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_6 = {'filter_num':64, 'filter_size':3, 'pad':1, 'stride':1},
                 hidden_size=50, output_size=10):
        # 重みの初期化===========
        # 各層のニューロンひとつあたりが、前層のニューロンといくつのつながりがあるか
        pre_node_nums = np.array([1*3*3, 16*3*3, 16*3*3, 32*3*3, 32*3*3, 64*3*3, 64*4*4, hidden_size])
        wight_init_scales = np.sqrt(2.0 / pre_node_nums)  # Heの初期値
        
        self.params = {}
        pre_channel_num = input_dim[0]
        for idx, conv_param in enumerate([conv_param_1, conv_param_2, conv_param_3, conv_param_4, conv_param_5, conv_param_6]):
            self.params['W' + str(idx+1)] = wight_init_scales[idx] * np.random.randn(conv_param['filter_num'], pre_channel_num, conv_param['filter_size'], conv_param['filter_size'])
            self.params['b' + str(idx+1)] = np.zeros(conv_param['filter_num'])
            pre_channel_num = conv_param['filter_num']
        self.params['W7'] = wight_init_scales[6] * np.random.randn(pre_node_nums[6], hidden_size)
        print(self.params['W7'].shape)
        self.params['b7'] = np.zeros(hidden_size)
        self.params['W8'] = wight_init_scales[7] * np.random.randn(pre_node_nums[7], output_size)
        self.params['b8'] = np.zeros(output_size)

        # レイヤの生成===========
        self.layers = []
        self.layers.append(layers.Convolution(self.params['W1'], self.params['b1'], 
                           conv_param_1['stride'], conv_param_1['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W2'], self.params['b2'], 
                           conv_param_2['stride'], conv_param_2['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Convolution(self.params['W3'], self.params['b3'], 
                           conv_param_3['stride'], conv_param_3['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W4'], self.params['b4'],
                           conv_param_4['stride'], conv_param_4['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Convolution(self.params['W5'], self.params['b5'],
                           conv_param_5['stride'], conv_param_5['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W6'], self.params['b6'],
                           conv_param_6['stride'], conv_param_6['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Affine(self.params['W7'], self.params['b7']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Dropout(0.5))
        self.layers.append(layers.Affine(self.params['W8'], self.params['b8']))
        self.layers.append(layers.Dropout(0.5))
        
        self.last_layer = layers.SoftmaxWithLoss()

    def predict(self, x, train_flg=False):
        for layer in self.layers:
            if isinstance(layer, layers.Dropout):
                x = layer.forward(x, train_flg)
            else:
                x = layer.forward(x)
        return x

    def loss(self, x, d):
        y = self.predict(x, train_flg=True)
        return self.last_layer.forward(y, d)

    def accuracy(self, x, d, batch_size=100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        acc = 0.0

        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx, train_flg=False)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td)

        return acc / x.shape[0]

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        tmp_layers = self.layers.copy()
        tmp_layers.reverse()
        for layer in tmp_layers:
            dout = layer.backward(dout)

        # 設定
        grads = {}
        for i, layer_idx in enumerate((0, 2, 5, 7, 10, 12, 15, 18)):
            grads['W' + str(i+1)] = self.layers[layer_idx].dW
            grads['b' + str(i+1)] = self.layers[layer_idx].db

        return grads

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]

print("データ読み込み完了")

network = DeepConvNet()  
optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)

    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# (1024, 50)
# Generation: 10. 正答率(トレーニング) = 0.1984
#                 : 10. 正答率(テスト) = 0.208
# Generation: 20. 正答率(トレーニング) = 0.4694
#                 : 20. 正答率(テスト) = 0.441
# Generation: 30. 正答率(トレーニング) = 0.595
#                 : 30. 正答率(テスト) = 0.546
# Generation: 40. 正答率(トレーニング) = 0.6584
#                 : 40. 正答率(テスト) = 0.626
# Generation: 50. 正答率(トレーニング) = 0.7844
#                 : 50. 正答率(テスト) = 0.734
# Generation: 60. 正答率(トレーニング) = 0.8024
#                 : 60. 正答率(テスト) = 0.784
# Generation: 70. 正答率(トレーニング) = 0.801
#                 : 70. 正答率(テスト) = 0.775
# Generation: 80. 正答率(トレーニング) = 0.8512
#                 : 80. 正答率(テスト) = 0.805
# Generation: 90. 正答率(トレーニング) = 0.9236
#                 : 90. 正答率(テスト) = 0.894
# Generation: 100. 正答率(トレーニング) = 0.9296
#                 : 100. 正答率(テスト) = 0.904
# Generation: 110. 正答率(トレーニング) = 0.932
#                 : 110. 正答率(テスト) = 0.918
# Generation: 120. 正答率(トレーニング) = 0.926
#                 : 120. 正答率(テスト) = 0.911
# Generation: 130. 正答率(トレーニング) = 0.9518
#                 : 130. 正答率(テスト) = 0.937
# Generation: 140. 正答率(トレーニング) = 0.9504
#                 : 140. 正答率(テスト) = 0.932
# Generation: 150. 正答率(トレーニング) = 0.9562
#                 : 150. 正答率(テスト) = 0.943
# Generation: 160. 正答率(トレーニング) = 0.9576
#                 : 160. 正答率(テスト) = 0.934
# Generation: 170. 正答率(トレーニング) = 0.9556
#                 : 170. 正答率(テスト) = 0.935
# Generation: 180. 正答率(トレーニング) = 0.9588
#                 : 180. 正答率(テスト) = 0.946
# Generation: 190. 正答率(トレーニング) = 0.9628
#                 : 190. 正答率(テスト) = 0.951
# Generation: 200. 正答率(トレーニング) = 0.9648
#                 : 200. 正答率(テスト) = 0.954
# Generation: 210. 正答率(トレーニング) = 0.9678
#                 : 210. 正答率(テスト) = 0.951
# Generation: 220. 正答率(トレーニング) = 0.971
#                 : 220. 正答率(テスト) = 0.955
# Generation: 230. 正答率(トレーニング) = 0.969
#                 : 230. 正答率(テスト) = 0.956
# Generation: 240. 正答率(トレーニング) = 0.9652
#                 : 240. 正答率(テスト) = 0.958
# Generation: 250. 正答率(トレーニング) = 0.9688
#                 : 250. 正答率(テスト) = 0.957
# Generation: 260. 正答率(トレーニング) = 0.97
#                 : 260. 正答率(テスト) = 0.952
# Generation: 270. 正答率(トレーニング) = 0.976
#                 : 270. 正答率(テスト) = 0.959
# Generation: 280. 正答率(トレーニング) = 0.973
#                 : 280. 正答率(テスト) = 0.955
# Generation: 290. 正答率(トレーニング) = 0.9796
#                 : 290. 正答率(テスト) = 0.959
# Generation: 300. 正答率(トレーニング) = 0.9798
#                 : 300. 正答率(テスト) = 0.959
# Generation: 310. 正答率(トレーニング) = 0.9788
#                 : 310. 正答率(テスト) = 0.959
# Generation: 320. 正答率(トレーニング) = 0.9808
#                 : 320. 正答率(テスト) = 0.968
# Generation: 330. 正答率(トレーニング) = 0.9754
#                 : 330. 正答率(テスト) = 0.958
# Generation: 340. 正答率(トレーニング) = 0.9828
#                 : 340. 正答率(テスト) = 0.965
# Generation: 350. 正答率(トレーニング) = 0.983
#                 : 350. 正答率(テスト) = 0.973
# Generation: 360. 正答率(トレーニング) = 0.9828
#                 : 360. 正答率(テスト) = 0.97
# Generation: 370. 正答率(トレーニング) = 0.9828
#                 : 370. 正答率(テスト) = 0.97
# Generation: 380. 正答率(トレーニング) = 0.9814
#                 : 380. 正答率(テスト) = 0.964
# Generation: 390. 正答率(トレーニング) = 0.9804
#                 : 390. 正答率(テスト) = 0.961
# Generation: 400. 正答率(トレーニング) = 0.9848
#                 : 400. 正答率(テスト) = 0.963
# Generation: 410. 正答率(トレーニング) = 0.9832
#                 : 410. 正答率(テスト) = 0.966
# Generation: 420. 正答率(トレーニング) = 0.982
#                 : 420. 正答率(テスト) = 0.966
# Generation: 430. 正答率(トレーニング) = 0.9824
#                 : 430. 正答率(テスト) = 0.971
# Generation: 440. 正答率(トレーニング) = 0.9828
#                 : 440. 正答率(テスト) = 0.97
# Generation: 450. 正答率(トレーニング) = 0.9814
#                 : 450. 正答率(テスト) = 0.968
# Generation: 460. 正答率(トレーニング) = 0.985
#                 : 460. 正答率(テスト) = 0.972
# Generation: 470. 正答率(トレーニング) = 0.9862
#                 : 470. 正答率(テスト) = 0.97
# Generation: 480. 正答率(トレーニング) = 0.985
#                 : 480. 正答率(テスト) = 0.964
# Generation: 490. 正答率(トレーニング) = 0.9842
#                 : 490. 正答率(テスト) = 0.965
# Generation: 500. 正答率(トレーニング) = 0.9866
#                 : 500. 正答率(テスト) = 0.972
# Generation: 510. 正答率(トレーニング) = 0.984
#                 : 510. 正答率(テスト) = 0.959
# Generation: 520. 正答率(トレーニング) = 0.983
#                 : 520. 正答率(テスト) = 0.964
# Generation: 530. 正答率(トレーニング) = 0.9878
#                 : 530. 正答率(テスト) = 0.972
# Generation: 540. 正答率(トレーニング) = 0.9882
#                 : 540. 正答率(テスト) = 0.972
# Generation: 550. 正答率(トレーニング) = 0.9866
#                 : 550. 正答率(テスト) = 0.969
# Generation: 560. 正答率(トレーニング) = 0.9836
#                 : 560. 正答率(テスト) = 0.957
# Generation: 570. 正答率(トレーニング) = 0.9884
#                 : 570. 正答率(テスト) = 0.973
# Generation: 580. 正答率(トレーニング) = 0.9896
#                 : 580. 正答率(テスト) = 0.974
# Generation: 590. 正答率(トレーニング) = 0.9882
#                 : 590. 正答率(テスト) = 0.974
# Generation: 600. 正答率(トレーニング) = 0.9898
#                 : 600. 正答率(テスト) = 0.979
# Generation: 610. 正答率(トレーニング) = 0.9884
#                 : 610. 正答率(テスト) = 0.981
# Generation: 620. 正答率(トレーニング) = 0.9904
#                 : 620. 正答率(テスト) = 0.976
# Generation: 630. 正答率(トレーニング) = 0.99
#                 : 630. 正答率(テスト) = 0.98
# Generation: 640. 正答率(トレーニング) = 0.9908
#                 : 640. 正答率(テスト) = 0.973
# Generation: 650. 正答率(トレーニング) = 0.9908
#                 : 650. 正答率(テスト) = 0.98
# Generation: 660. 正答率(トレーニング) = 0.9908
#                 : 660. 正答率(テスト) = 0.98
# Generation: 670. 正答率(トレーニング) = 0.9914
#                 : 670. 正答率(テスト) = 0.977
# Generation: 680. 正答率(トレーニング) = 0.9914
#                 : 680. 正答率(テスト) = 0.98
# Generation: 690. 正答率(トレーニング) = 0.9924
#                 : 690. 正答率(テスト) = 0.978
# Generation: 700. 正答率(トレーニング) = 0.9924
#                 : 700. 正答率(テスト) = 0.98
# Generation: 710. 正答率(トレーニング) = 0.992
#                 : 710. 正答率(テスト) = 0.98
# Generation: 720. 正答率(トレーニング) = 0.9932
#                 : 720. 正答率(テスト) = 0.978
# Generation: 730. 正答率(トレーニング) = 0.9892
#                 : 730. 正答率(テスト) = 0.977
# Generation: 740. 正答率(トレーニング) = 0.9932
#                 : 740. 正答率(テスト) = 0.978
# Generation: 750. 正答率(トレーニング) = 0.9932
#                 : 750. 正答率(テスト) = 0.975
# Generation: 760. 正答率(トレーニング) = 0.9922
#                 : 760. 正答率(テスト) = 0.981
# Generation: 770. 正答率(トレーニング) = 0.9928
#                 : 770. 正答率(テスト) = 0.982
# Generation: 780. 正答率(トレーニング) = 0.9936
#                 : 780. 正答率(テスト) = 0.986
# Generation: 790. 正答率(トレーニング) = 0.9916
#                 : 790. 正答率(テスト) = 0.983
# Generation: 800. 正答率(トレーニング) = 0.9936
#                 : 800. 正答率(テスト) = 0.985
# Generation: 810. 正答率(トレーニング) = 0.994
#                 : 810. 正答率(テスト) = 0.98
# Generation: 820. 正答率(トレーニング) = 0.994
#                 : 820. 正答率(テスト) = 0.98
# Generation: 830. 正答率(トレーニング) = 0.993
#                 : 830. 正答率(テスト) = 0.98
# Generation: 840. 正答率(トレーニング) = 0.9942
#                 : 840. 正答率(テスト) = 0.985
# Generation: 850. 正答率(トレーニング) = 0.9942
#                 : 850. 正答率(テスト) = 0.977
# Generation: 860. 正答率(トレーニング) = 0.9946
#                 : 860. 正答率(テスト) = 0.984
# Generation: 870. 正答率(トレーニング) = 0.9926
#                 : 870. 正答率(テスト) = 0.984
# Generation: 880. 正答率(トレーニング) = 0.9948
#                 : 880. 正答率(テスト) = 0.985
# Generation: 890. 正答率(トレーニング) = 0.995
#                 : 890. 正答率(テスト) = 0.98
# Generation: 900. 正答率(トレーニング) = 0.9948
#                 : 900. 正答率(テスト) = 0.983
# Generation: 910. 正答率(トレーニング) = 0.9904
#                 : 910. 正答率(テスト) = 0.975
# Generation: 920. 正答率(トレーニング) = 0.9934
#                 : 920. 正答率(テスト) = 0.979
# Generation: 930. 正答率(トレーニング) = 0.9944
#                 : 930. 正答率(テスト) = 0.98
# Generation: 940. 正答率(トレーニング) = 0.9932
#                 : 940. 正答率(テスト) = 0.977
# Generation: 950. 正答率(トレーニング) = 0.9956
#                 : 950. 正答率(テスト) = 0.983
# Generation: 960. 正答率(トレーニング) = 0.9964
#                 : 960. 正答率(テスト) = 0.98
# Generation: 970. 正答率(トレーニング) = 0.996
#                 : 970. 正答率(テスト) = 0.983
# Generation: 980. 正答率(トレーニング) = 0.997
#                 : 980. 正答率(テスト) = 0.98
# Generation: 990. 正答率(トレーニング) = 0.9964
#                 : 990. 正答率(テスト) = 0.981
# Generation: 1000. 正答率(トレーニング) = 0.9952
#                 : 1000. 正答率(テスト) = 0.975
